# %% [markdown]
# # Set-up

# %%
# ! pip install altair
# ! pip install altair_saver

# %%
import altair as alt
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import time

from altair_saver import save
from datetime import datetime
from sseclient import SSEClient as EventSource

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# # Data collection

# %%
url = 'https://stream.wikimedia.org/v2/stream/recentchange'
dataset = []
events_counter = 0
time_threshold = 60.0
t_0  = time.time()

for event in EventSource(url): # start streaming
    if event.event == 'message':
        try:
            change = json.loads(event.data)
        except ValueError:
            continue
            
        events_counter += 1
        user_hash = hash(change['user'])
        
        if user_hash % 10 < 2: # filter
            dataset.append(change)
            
        if (time.time() - t_0)//60 > time_threshold:
            break
            
df = pd.DataFrame(dataset)
df.to_csv(f'dataset_{t_0}.csv')

# %% [markdown]
# ## Import after preparation

# %%
# reading prepared dataset
df = pd.read_csv('https://raw.githubusercontent.com/madmalewolf/stat-open-/main/all_data.tsv.gz', sep='\t', compression='gzip',)
print(f'df.shape = {df.shape}')
df.head(2)
# Out:
# df.shape = (120467, 26)
#    Unnamed: 0  Unnamed: 0.1                        $schema  \
# 0           0             0  /mediawiki/recentchange/1.0.0
# 1           1             1  /mediawiki/recentchange/1.0.0
#
#                                                 meta            id  type  \
# 0  {'uri': 'https://www.wikidata.org/wiki/Q108828...  1.556609e+09  edit
# 1  {'uri': 'https://www.wikidata.org/wiki/Q175855...  1.556609e+09  edit
#
#    namespace       title                                            comment  \
# 0          0  Q108828195  /* wbsetreference-add:2| */ [[Property:P570]]:...
# 1          0   Q17585531  /* wbsetreference-set:2| */ [[Property:P141]]:...
#
#     timestamp         user    bot  minor patrolled  \
# 0  1633634790  Quesotiotyo  False  False      True
# 1  1633634789     SuccuBot   True  False      True
#
#                          length                                revision  \
# 0  {'old': 28649, 'new': 29712}  {'old': 1509178938, 'new': 1509178965}
# 1  {'old': 16134, 'new': 16134}  {'old': 1458793714, 'new': 1509178961}
#
#                  server_url       server_name server_script_path  \
# 0  https://www.wikidata.org  www.wikidata.org                 /w
# 1  https://www.wikidata.org  www.wikidata.org                 /w
#
#            wiki                                      parsedcomment  log_id  \
# 0  wikidatawiki  ‎<span dir="auto"><span class="autocomment">Ad...     NaN
# 1  wikidatawiki  ‎<span dir="auto"><span class="autocomment">Fu...     NaN
#
#   log_type log_action log_params log_action_comment
# 0      NaN        NaN        NaN                NaN
# 1      NaN        NaN        NaN                NaN

# %% [markdown]
# # Data exploration

# %% [markdown]
# ## Number of changes done by user

# %%
os.makedirs('charts', exist_ok=True) # create dir for charts

gd_dict = {row['user']: row['bot'] for _, row in df.iterrows()}
df_counts = df.user.value_counts().reset_index()
df_counts.columns = ['user', 'changes']
df_counts['bot'] = df_counts.user.map(lambda x: gd_dict[x])
df_counts.head()

np.random.seed(42)
sample_df = df_counts.sample(min(df_counts.shape[0], 400))

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user')]
).properties(
    width = 600,
    height = 400,
    title = 'Number of changes by user'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [alt.Tooltip('count()', title='No of users')]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart = chart_counts | chart_bots

save(chart, 'charts/total_number_changes.html')

# %% [markdown]
# ## Avg number of changes done by user per timestamp

# %%
# df['timestamp_parsed'] = df.timestamp.map(lambda x: datetime.fromtimestamp(x))

avg_changes_per_timestamp = df[['user', 'timestamp']].value_counts().groupby('user').mean().reset_index()
avg_changes_per_timestamp.columns = ['user', 'changes_per_timestamp']
avg_changes_per_timestamp['bot'] = avg_changes_per_timestamp.user.map(lambda x: gd_dict[x])

np.random.seed(42)
sample_df = avg_changes_per_timestamp.sample(min(avg_changes_per_timestamp.shape[0], 400))

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes_per_timestamp:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user'), alt.Tooltip('changes_per_timestamp:Q')]
).properties(
    width = 600,
    height = 400,
    title = 'Avg number of changes by user per timestamp'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [alt.Tooltip('count()', title='No of users')]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart = chart_counts | chart_bots

save(chart, 'charts/avg_number_changes_per_timestamp.html')

# %% [markdown]
# ## Avg number of changes done by user per timestamp (balanced by bot/not bot)

# %%
avg_changes_per_timestamp = df[['user', 'timestamp']].value_counts().groupby('user').mean().reset_index()
avg_changes_per_timestamp.columns = ['user', 'changes_per_timestamp']
avg_changes_per_timestamp['bot'] = avg_changes_per_timestamp.user.map(lambda x: gd_dict[x])

np.random.seed(42)
num = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].shape[0]
bot_sample_df = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].sample(num)
not_bot_sample_df = avg_changes_per_timestamp[~avg_changes_per_timestamp.bot].sample(num)

sample_df = pd.concat([bot_sample_df, not_bot_sample_df])

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes_per_timestamp:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user'), alt.Tooltip('changes_per_timestamp:Q')]
).properties(
    width = 600,
    height = 400,
    title = 'Avg number of changes by user per timestamp'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [
        alt.Tooltip('count()', title='No of users'), 
        alt.Tooltip('bot')
    ]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart = chart_counts | chart_bots

save(chart, 'charts/avg_number_changes_per_timestamp_balanced.html')

# %%
sample_df[['changes_per_timestamp', 'bot']].groupby('bot').mean()
# Out:
#        changes_per_timestamp
# bot
# False               1.477535
# True                1.655237

# %% [markdown]
# ## Avg number of changes done by user per timestamp (balanced by bot/not bot) having more than 1 change

# %%
avg_changes_per_timestamp = df[['user', 'timestamp']].value_counts().groupby('user').mean().reset_index()
avg_changes_per_timestamp.columns = ['user', 'changes_per_timestamp']
avg_changes_per_timestamp['bot'] = avg_changes_per_timestamp.user.map(lambda x: gd_dict[x])

avg_changes_per_timestamp = avg_changes_per_timestamp[avg_changes_per_timestamp.changes_per_timestamp > 1.]

num = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].shape[0]
print(f'There are {num} bots')

np.random.seed(42)
bot_sample_df = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].sample(num)
not_bot_sample_df = avg_changes_per_timestamp[~avg_changes_per_timestamp.bot].sample(num)

sample_df = pd.concat([bot_sample_df, not_bot_sample_df])

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes_per_timestamp:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user'), alt.Tooltip('changes_per_timestamp:Q')]
).properties(
    width = 600,
    height = 400,
    title = 'Avg number of changes by user per timestamp with more than 1 change'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [
        alt.Tooltip('count()', title='No of users'), 
        alt.Tooltip('bot')
    ]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart = chart_counts | chart_bots

save(chart, 'charts/avg_number_changes_per_timestamp_balanced_with_filter.html')
# Out:
# There are 76 bots

# %%
sample_df[['changes_per_timestamp', 'bot']].groupby('bot').mean()
# Out:
#        changes_per_timestamp
# bot
# False               2.738688
# True                2.163909

# %%
df[(df.user == 'Phediuk')&(df.timestamp == 1633643510)]
# Out:
#        Unnamed: 0  Unnamed: 0.1                        $schema  \
# 15504        8066          8066  /mediawiki/recentchange/1.0.0
# 15507        8069          8069  /mediawiki/recentchange/1.0.0
# 15508        8070          8070  /mediawiki/recentchange/1.0.0
# 15510        8072          8072  /mediawiki/recentchange/1.0.0
#
#                                                     meta            id  \
# 15504  {'uri': 'https://en.wikipedia.org/wiki/Day_of_...  1.430680e+09
# 15507  {'uri': 'https://en.wikipedia.org/wiki/Categor...  1.430680e+09
# 15508  {'uri': 'https://en.wikipedia.org/wiki/Categor...  1.430680e+09
# 15510  {'uri': 'https://en.wikipedia.org/wiki/Categor...  1.430680e+09
#
#              type  namespace  \
# 15504        edit          0
# 15507  categorize         14
# 15508  categorize         14
# 15510  categorize         14
#
#                                                    title  \
# 15504                               Day of the Figurines
# 15507                          Category:2005 video games
# 15508        Category:Massively multiplayer online games
# 15510  Category:Video games developed in the United K...
#
#                                                  comment   timestamp     user  \
# 15504                                                NaN  1633643510  Phediuk
# 15507  [[:Day of the Figurines]] added to category, [...  1633643510  Phediuk
# 15508  [[:Day of the Figurines]] added to category, [...  1633643510  Phediuk
# 15510  [[:Day of the Figurines]] added to category, [...  1633643510  Phediuk
#
#          bot  minor patrolled                      length  \
# 15504  False  False       NaN  {'old': 2292, 'new': 2426}
# 15507  False    NaN       NaN                         NaN
# 15508  False    NaN       NaN                         NaN
# 15510  False    NaN       NaN                         NaN
#
#                                     revision                server_url  \
# 15504  {'old': 987420945, 'new': 1048773585}  https://en.wikipedia.org
# 15507                                    NaN  https://en.wikipedia.org
# 15508                                    NaN  https://en.wikipedia.org
# 15510                                    NaN  https://en.wikipedia.org
#
#             server_name server_script_path    wiki  \
# 15504  en.wikipedia.org                 /w  enwiki
# 15507  en.wikipedia.org                 /w  enwiki
# 15508  en.wikipedia.org                 /w  enwiki
# 15510  en.wikipedia.org                 /w  enwiki
#
#                                            parsedcomment  log_id log_type  \
# 15504                                                NaN     NaN      NaN
# 15507  <a href="/wiki/Day_of_the_Figurines" title="Da...     NaN      NaN
# 15508  <a href="/wiki/Day_of_the_Figurines" title="Da...     NaN      NaN
# 15510  <a href="/wiki/Day_of_the_Figurines" title="Da...     NaN      NaN
#
#       log_action log_params log_action_comment
# 15504        NaN        NaN                NaN
# 15507        NaN        NaN                NaN
# 15508        NaN        NaN                NaN
# 15510        NaN        NaN                NaN

# %%
df[(df.user == 'Prairie Astronomer')&(df.timestamp == 1633653280)]
# Out:
#        Unnamed: 0  Unnamed: 0.1                        $schema  \
# 38386       30948         30948  /mediawiki/recentchange/1.0.0
# 38392       30954         30954  /mediawiki/recentchange/1.0.0
# 38393       30955         30955  /mediawiki/recentchange/1.0.0
# 38394       30956         30956  /mediawiki/recentchange/1.0.0
# 38395       30957         30957  /mediawiki/recentchange/1.0.0
#
#                                                     meta            id  \
# 38386  {'uri': 'https://en.wikipedia.org/wiki/Talk:20...  1.430713e+09
# 38392  {'uri': 'https://en.wikipedia.org/wiki/Categor...  1.430713e+09
# 38393  {'uri': 'https://en.wikipedia.org/wiki/Categor...  1.430713e+09
# 38394  {'uri': 'https://en.wikipedia.org/wiki/Categor...  1.430713e+09
# 38395  {'uri': 'https://en.wikipedia.org/wiki/Categor...  1.430713e+09
#
#              type  namespace  \
# 38386        edit          1
# 38392  categorize         14
# 38393  categorize         14
# 38394  categorize         14
# 38395  categorize         14
#
#                                                    title  \
# 38386                   Talk:2021 Balochistan earthquake
# 38392  Category:Mid-importance Disaster management ar...
# 38393          Category:Low-importance Pakistan articles
# 38394  Category:Unknown-importance Disaster managemen...
# 38395      Category:Unknown-importance Pakistan articles
#
#                                                  comment   timestamp  \
# 38386  Assessment: banner shell, Disaster management ...  1633653280
# 38392  [[:Talk:2021 Balochistan earthquake]] added to...  1633653280
# 38393  [[:Talk:2021 Balochistan earthquake]] added to...  1633653280
# 38394  [[:Talk:2021 Balochistan earthquake]] removed ...  1633653280
# 38395  [[:Talk:2021 Balochistan earthquake]] removed ...  1633653280
#
#                      user    bot  minor patrolled                    length  \
# 38386  Prairie Astronomer  False  False       NaN  {'old': 230, 'new': 293}
# 38392  Prairie Astronomer  False    NaN       NaN                       NaN
# 38393  Prairie Astronomer  False    NaN       NaN                       NaN
# 38394  Prairie Astronomer  False    NaN       NaN                       NaN
# 38395  Prairie Astronomer  False    NaN       NaN                       NaN
#
#                                      revision                server_url  \
# 38386  {'old': 1048758694, 'new': 1048790189}  https://en.wikipedia.org
# 38392                                     NaN  https://en.wikipedia.org
# 38393                                     NaN  https://en.wikipedia.org
# 38394                                     NaN  https://en.wikipedia.org
# 38395                                     NaN  https://en.wikipedia.org
#
#             server_name server_script_path    wiki  \
# 38386  en.wikipedia.org                 /w  enwiki
# 38392  en.wikipedia.org                 /w  enwiki
# 38393  en.wikipedia.org                 /w  enwiki
# 38394  en.wikipedia.org                 /w  enwiki
# 38395  en.wikipedia.org                 /w  enwiki
#
#                                            parsedcomment  log_id log_type  \
# 38386  Assessment: banner shell, Disaster management ...     NaN      NaN
# 38392  <a href="/wiki/Talk:2021_Balochistan_earthquak...     NaN      NaN
# 38393  <a href="/wiki/Talk:2021_Balochistan_earthquak...     NaN      NaN
# 38394  <a href="/wiki/Talk:2021_Balochistan_earthquak...     NaN      NaN
# 38395  <a href="/wiki/Talk:2021_Balochistan_earthquak...     NaN      NaN
#
#       log_action log_params log_action_comment
# 38386        NaN        NaN                NaN
# 38392        NaN        NaN                NaN
# 38393        NaN        NaN                NaN
# 38394        NaN        NaN                NaN
# 38395        NaN        NaN                NaN

# %% [markdown]
# ## Change type analysis

# %%
df.type.value_counts()
# Out:
# edit          75857
# categorize    29798
# log           11134
# new            3653
# 142              25
# Name: type, dtype: int64

# %%
df[['type', 'bot', 'minor']].value_counts()
# Out:
# type  bot    minor
# edit  False  False    34630
#       True   False    29800
#       False  True      6379
#       True   True      5048
# new   False  False     2762
#       True   False      891
# dtype: int64

# %%
df_edits = df[df.type == 'edit']
df_edits.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1                        $schema  \
# 0           0             0  /mediawiki/recentchange/1.0.0
# 1           1             1  /mediawiki/recentchange/1.0.0
#
#                                                 meta            id  type  \
# 0  {'uri': 'https://www.wikidata.org/wiki/Q108828...  1.556609e+09  edit
# 1  {'uri': 'https://www.wikidata.org/wiki/Q175855...  1.556609e+09  edit
#
#    namespace       title                                            comment  \
# 0          0  Q108828195  /* wbsetreference-add:2| */ [[Property:P570]]:...
# 1          0   Q17585531  /* wbsetreference-set:2| */ [[Property:P141]]:...
#
#     timestamp         user    bot  minor patrolled  \
# 0  1633634790  Quesotiotyo  False  False      True
# 1  1633634789     SuccuBot   True  False      True
#
#                          length                                revision  \
# 0  {'old': 28649, 'new': 29712}  {'old': 1509178938, 'new': 1509178965}
# 1  {'old': 16134, 'new': 16134}  {'old': 1458793714, 'new': 1509178961}
#
#                  server_url       server_name server_script_path  \
# 0  https://www.wikidata.org  www.wikidata.org                 /w
# 1  https://www.wikidata.org  www.wikidata.org                 /w
#
#            wiki                                      parsedcomment  log_id  \
# 0  wikidatawiki  ‎<span dir="auto"><span class="autocomment">Ad...     NaN
# 1  wikidatawiki  ‎<span dir="auto"><span class="autocomment">Fu...     NaN
#
#   log_type log_action log_params log_action_comment
# 0      NaN        NaN        NaN                NaN
# 1      NaN        NaN        NaN                NaN

# %% [markdown]
# ## Avg number of edits done by user per timestamp (balanced by bot/not bot) having more than 1 change

# %%
avg_changes_per_timestamp = df_edits[['user', 'timestamp']].value_counts().groupby('user').mean().reset_index()
avg_changes_per_timestamp.columns = ['user', 'changes_per_timestamp']
avg_changes_per_timestamp['bot'] = avg_changes_per_timestamp.user.map(lambda x: gd_dict[x])

avg_changes_per_timestamp = avg_changes_per_timestamp[avg_changes_per_timestamp.changes_per_timestamp > 1.]

num = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].shape[0]
print(f'There are {num} bots')

np.random.seed(42)
bot_sample_df = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].sample(num)
not_bot_sample_df = avg_changes_per_timestamp[~avg_changes_per_timestamp.bot].sample(num)

sample_df = pd.concat([bot_sample_df, not_bot_sample_df])

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes_per_timestamp:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user'), alt.Tooltip('changes_per_timestamp:Q')]
).properties(
    width = 600,
    height = 400,
    title = 'Avg number of edits by user per timestamp with more than 1 change'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [
        alt.Tooltip('count()', title='No of users'), 
        alt.Tooltip('bot')
    ]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart = chart_counts | chart_bots

save(chart, 'charts/avg_number_changes_per_timestamp_balanced_with_filter.html')
# Out:
# There are 36 bots

# %%
df_edits[df_edits.user == 'Jamc2'].head()
# Out:
#       Unnamed: 0  Unnamed: 0.1                        $schema  \
# 37            37            37  /mediawiki/recentchange/1.0.0
# 38            38            38  /mediawiki/recentchange/1.0.0
# 40            40            40  /mediawiki/recentchange/1.0.0
# 900          900           900  /mediawiki/recentchange/1.0.0
# 6132        6132          6132  /mediawiki/recentchange/1.0.0
#
#                                                    meta            id  type  \
# 37    {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784906e+09  edit
# 38    {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784906e+09  edit
# 40    {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784906e+09  edit
# 900   {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784908e+09  edit
# 6132  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784922e+09  edit
#
#       namespace                                              title  \
# 37            6  File:Wild flowers in stubble field - geograph....
# 38            6  File:View towards Howard's Hill - geograph.org...
# 40            6  File:Where is the footpath - geograph.org.uk -...
# 900           6  File:Cragside - Leeds Road, Windhill - geograp...
# 6132          6  File:Boyne Street - Hopwood Lane - geograph.or...
#
#                                                 comment   timestamp   user  \
# 37    Copying from [[Category:United Kingdom photogr...  1633634797  Jamc2
# 38    Copying from [[Category:United Kingdom photogr...  1633634797  Jamc2
# 40    Copying from [[Category:United Kingdom photogr...  1633634797  Jamc2
# 900   Copying from [[Category:United Kingdom photogr...  1633634976  Jamc2
# 6132  Copying from [[Category:United Kingdom photogr...  1633636307  Jamc2
#
#         bot minor patrolled                      length  \
# 37    False  True      True  {'old': 6857, 'new': 6904}
# 38    False  True      True  {'old': 7362, 'new': 7409}
# 40    False  True      True  {'old': 7550, 'new': 7597}
# 900   False  True      True  {'old': 6494, 'new': 6533}
# 6132  False  True      True  {'old': 6453, 'new': 6522}
#
#                                   revision                     server_url  \
# 37    {'old': 538914825, 'new': 596582011}  https://commons.wikimedia.org
# 38    {'old': 538913003, 'new': 596582010}  https://commons.wikimedia.org
# 40    {'old': 538914589, 'new': 596582007}  https://commons.wikimedia.org
# 900   {'old': 578058026, 'new': 596583273}  https://commons.wikimedia.org
# 6132  {'old': 538920102, 'new': 596591492}  https://commons.wikimedia.org
#
#                 server_name server_script_path         wiki  \
# 37    commons.wikimedia.org                 /w  commonswiki
# 38    commons.wikimedia.org                 /w  commonswiki
# 40    commons.wikimedia.org                 /w  commonswiki
# 900   commons.wikimedia.org                 /w  commonswiki
# 6132  commons.wikimedia.org                 /w  commonswiki
#
#                                           parsedcomment  log_id log_type  \
# 37    Copying from <a href="/wiki/Category:United_Ki...     NaN      NaN
# 38    Copying from <a href="/wiki/Category:United_Ki...     NaN      NaN
# 40    Copying from <a href="/wiki/Category:United_Ki...     NaN      NaN
# 900   Copying from <a href="/wiki/Category:United_Ki...     NaN      NaN
# 6132  Copying from <a href="/wiki/Category:United_Ki...     NaN      NaN
#
#      log_action log_params log_action_comment
# 37          NaN        NaN                NaN
# 38          NaN        NaN                NaN
# 40          NaN        NaN                NaN
# 900         NaN        NaN                NaN
# 6132        NaN        NaN                NaN

# %%
sample_df[['changes_per_timestamp', 'bot']].groupby('bot').mean()
# Out:
#        changes_per_timestamp
# bot
# False               1.863656
# True                1.509182

# %% [markdown]
# # Max number of edits done by user per timestamp (balanced by bot/not bot) having more than 1 change

# %%
avg_changes_per_timestamp = df_edits[['user', 'timestamp']].value_counts().groupby('user').max().reset_index()
avg_changes_per_timestamp.columns = ['user', 'changes_per_timestamp']
avg_changes_per_timestamp['bot'] = avg_changes_per_timestamp.user.map(lambda x: gd_dict[x])

avg_changes_per_timestamp = avg_changes_per_timestamp[avg_changes_per_timestamp.changes_per_timestamp > 1.]

num = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].shape[0]
print(f'There are {num} bots')

np.random.seed(42)
bot_sample_df = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].sample(num)
not_bot_sample_df = avg_changes_per_timestamp[~avg_changes_per_timestamp.bot].sample(num)

sample_df = pd.concat([bot_sample_df, not_bot_sample_df])

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes_per_timestamp:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user'), alt.Tooltip('changes_per_timestamp:Q')]
).properties(
    width = 600,
    height = 400,
    title = 'Max number of edits by user per timestamp with more than 1 change'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [
        alt.Tooltip('count()', title='No of users'), 
        alt.Tooltip('bot')
    ]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart = chart_counts | chart_bots

save(chart, 'charts/max_number_changes_per_timestamp_balanced_with_filter.html')
# Out:
# There are 36 bots

# %%
sample_df[['changes_per_timestamp', 'bot']].groupby('bot').max()
# Out:
#        changes_per_timestamp
# bot
# False                     19
# True                      18

# %%
sample_df[['changes_per_timestamp', 'bot']].groupby('bot').min()
# Out:
#        changes_per_timestamp
# bot
# False                      2
# True                       2
