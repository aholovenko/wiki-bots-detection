# %% [markdown]
# # Data collection

# %%
import altair as alt
import json
import matplotlib.pyplot as plt
import os
import pandas as pd
import time
from sseclient import SSEClient as EventSource

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
url = 'https://stream.wikimedia.org/v2/stream/recentchange'
dataset = []
events_counter = 0
time_threshold = 60.0
t_0  = time.time()

for event in EventSource(url): # start streaming
    if event.event == 'message':
        try:
            change = json.loads(event.data)
        except ValueError:
            continue
            
        events_counter += 1
        user_hash = hash(change['user'])
        if user_hash % 10 < 2:
            dataset.append(change)
            
        if (time.time() - t_0)//60 > time_threshold:
            break
            
        if events_counter % 1000 == 0:
            print('saving data')
            df = pd.DataFrame(dataset)
            df.to_csv(f'dataset_{t_0}.csv')
            
df = pd.DataFrame(dataset)
df.to_csv(f'dataset_{t_0}.csv')
# Out:
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
#
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
#
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
#
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
# saving data
#
# saving data

# %%
len(dataset), events_counter, len(dataset)*100/events_counter
# Out:
# (36013, 305470, 11.789373751923266)

# %% [markdown]
# # Data exploration

# %% [markdown]
# ## Number of changes done by user

# %%
# ! pip install altair
import altair as alt
import numpy as np
import pandas as pd

gd_dict = {row['user']: row['bot'] for _, row in df.iterrows()}
df_counts = df.user.value_counts().reset_index()
df_counts.columns = ['user', 'changes']
df_counts['bot'] = df_counts.user.map(lambda x: gd_dict[x])
df_counts.head()

np.random.seed(42)
sample_df = df_counts.sample(400)

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user')]
).properties(
    width = 600,
    height = 400,
    title = 'Number of changes by user'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [alt.Tooltip('count()', title='No of users')]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart_counts | chart_bots
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ## Avg number of changes done by user per timestamp

# %%
from datetime import datetime

df['timestamp_parsed'] = df.timestamp.map(lambda x: datetime.fromtimestamp(x))

avg_changes_per_timestamp = df[['user', 'timestamp']].value_counts().groupby('user').mean().reset_index()
avg_changes_per_timestamp.columns = ['user', 'changes_per_timestamp']
avg_changes_per_timestamp['bot'] = avg_changes_per_timestamp.user.map(lambda x: gd_dict[x])

np.random.seed(42)
sample_df = avg_changes_per_timestamp.sample(400)

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes_per_timestamp:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user'), alt.Tooltip('changes_per_timestamp:Q')]
).properties(
    width = 600,
    height = 400,
    title = 'Number of changes by user per timestamp'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [alt.Tooltip('count()', title='No of users')]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart_counts | chart_bots
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ## Avg number of changes done by user per timestamp (balanced by bot/not bot)

# %%
from datetime import datetime

df['timestamp_parsed'] = df.timestamp.map(lambda x: datetime.fromtimestamp(x))

avg_changes_per_timestamp = df[['user', 'timestamp']].value_counts().groupby('user').mean().reset_index()
avg_changes_per_timestamp.columns = ['user', 'changes_per_timestamp']
avg_changes_per_timestamp['bot'] = avg_changes_per_timestamp.user.map(lambda x: gd_dict[x])

np.random.seed(42)
num = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].shape[0]
bot_sample_df = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].sample(num)
not_bot_sample_df = avg_changes_per_timestamp[~avg_changes_per_timestamp.bot].sample(num)

sample_df = pd.concat([bot_sample_df, not_bot_sample_df])

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes_per_timestamp:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user'), alt.Tooltip('changes_per_timestamp:Q')]
).properties(
    width = 600,
    height = 400,
    title = 'Number of changes by user per timestamp'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [
        alt.Tooltip('count()', title='No of users'), 
        alt.Tooltip('bot')
    ]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart_counts | chart_bots
# Out:
# alt.HConcatChart(...)

# %%
sample_df[['changes_per_timestamp', 'bot']][sample_df.changes_per_timestamp > 1].groupby('bot').mean()
# Out:
#        changes_per_timestamp
# bot
# False               3.070322
# True                1.930707

# %% [markdown]
# ## Avg number of changes done by user per timestamp (balanced by bot/not bot and with more than 1 change)

# %%
from datetime import datetime

df['timestamp_parsed'] = df.timestamp.map(lambda x: datetime.fromtimestamp(x))

avg_changes_per_timestamp = df[['user', 'timestamp']].value_counts().groupby('user').mean().reset_index()
avg_changes_per_timestamp.columns = ['user', 'changes_per_timestamp']
avg_changes_per_timestamp['bot'] = avg_changes_per_timestamp.user.map(lambda x: gd_dict[x])

np.random.seed(42)

avg_changes_per_timestamp = avg_changes_per_timestamp[avg_changes_per_timestamp.changes_per_timestamp > 1.]

num = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].shape[0]
print(f'There are {num} bots')

bot_sample_df = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].sample(num)
not_bot_sample_df = avg_changes_per_timestamp[~avg_changes_per_timestamp.bot].sample(num)

sample_df = pd.concat([bot_sample_df, not_bot_sample_df])

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes_per_timestamp:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user'), alt.Tooltip('changes_per_timestamp:Q')]
).properties(
    width = 600,
    height = 400,
    title = 'Number of changes by user per timestamp with more than 1 change'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [
        alt.Tooltip('count()', title='No of users'), 
        alt.Tooltip('bot')
    ]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart_counts | chart_bots
# Out:
# There are 27 bots
# alt.HConcatChart(...)

# %%
sample_df[['changes_per_timestamp', 'bot']].groupby('bot').mean()
# Out:
#        changes_per_timestamp
# bot
# False               2.036153
# True                1.930707

# %%
df[(df.user == 'Phediuk')&(df.timestamp == 1633643510)]
# Out:
#                             $schema  \
# 8066  /mediawiki/recentchange/1.0.0
# 8069  /mediawiki/recentchange/1.0.0
# 8070  /mediawiki/recentchange/1.0.0
# 8072  /mediawiki/recentchange/1.0.0
#
#                                                    meta        type  \
# 8066  {'uri': 'https://en.wikipedia.org/wiki/Day_of_...        edit
# 8069  {'uri': 'https://en.wikipedia.org/wiki/Categor...  categorize
# 8070  {'uri': 'https://en.wikipedia.org/wiki/Categor...  categorize
# 8072  {'uri': 'https://en.wikipedia.org/wiki/Categor...  categorize
#
#       namespace                                              title  \
# 8066          0                               Day of the Figurines
# 8069         14                          Category:2005 video games
# 8070         14        Category:Massively multiplayer online games
# 8072         14  Category:Video games developed in the United K...
#
#                                                 comment   timestamp     user  \
# 8066                                                     1633643510  Phediuk
# 8069  [[:Day of the Figurines]] added to category, [...  1633643510  Phediuk
# 8070  [[:Day of the Figurines]] added to category, [...  1633643510  Phediuk
# 8072  [[:Day of the Figurines]] added to category, [...  1633643510  Phediuk
#
#         bot  log_id log_type log_action log_params log_action_comment  \
# 8066  False     NaN      NaN        NaN        NaN                NaN
# 8069  False     NaN      NaN        NaN        NaN                NaN
# 8070  False     NaN      NaN        NaN        NaN                NaN
# 8072  False     NaN      NaN        NaN        NaN                NaN
#
#                     server_url       server_name server_script_path    wiki  \
# 8066  https://en.wikipedia.org  en.wikipedia.org                 /w  enwiki
# 8069  https://en.wikipedia.org  en.wikipedia.org                 /w  enwiki
# 8070  https://en.wikipedia.org  en.wikipedia.org                 /w  enwiki
# 8072  https://en.wikipedia.org  en.wikipedia.org                 /w  enwiki
#
#                                           parsedcomment            id  minor  \
# 8066                                                     1.430680e+09  False
# 8069  <a href="/wiki/Day_of_the_Figurines" title="Da...  1.430680e+09    NaN
# 8070  <a href="/wiki/Day_of_the_Figurines" title="Da...  1.430680e+09    NaN
# 8072  <a href="/wiki/Day_of_the_Figurines" title="Da...  1.430680e+09    NaN
#
#      patrolled                      length  \
# 8066       NaN  {'old': 2292, 'new': 2426}
# 8069       NaN                         NaN
# 8070       NaN                         NaN
# 8072       NaN                         NaN
#
#                                    revision    timestamp_parsed
# 8066  {'old': 987420945, 'new': 1048773585} 2021-10-08 00:51:50
# 8069                                    NaN 2021-10-08 00:51:50
# 8070                                    NaN 2021-10-08 00:51:50
# 8072                                    NaN 2021-10-08 00:51:50

# %%
df[(df.user == 'Prairie Astronomer')&(df.timestamp == 1633653280)]
# Out:
#                              $schema  \
# 30948  /mediawiki/recentchange/1.0.0
# 30954  /mediawiki/recentchange/1.0.0
# 30955  /mediawiki/recentchange/1.0.0
# 30956  /mediawiki/recentchange/1.0.0
# 30957  /mediawiki/recentchange/1.0.0
#
#                                                     meta        type  \
# 30948  {'uri': 'https://en.wikipedia.org/wiki/Talk:20...        edit
# 30954  {'uri': 'https://en.wikipedia.org/wiki/Categor...  categorize
# 30955  {'uri': 'https://en.wikipedia.org/wiki/Categor...  categorize
# 30956  {'uri': 'https://en.wikipedia.org/wiki/Categor...  categorize
# 30957  {'uri': 'https://en.wikipedia.org/wiki/Categor...  categorize
#
#        namespace                                              title  \
# 30948          1                   Talk:2021 Balochistan earthquake
# 30954         14  Category:Mid-importance Disaster management ar...
# 30955         14          Category:Low-importance Pakistan articles
# 30956         14  Category:Unknown-importance Disaster managemen...
# 30957         14      Category:Unknown-importance Pakistan articles
#
#                                                  comment   timestamp  \
# 30948  Assessment: banner shell, Disaster management ...  1633653280
# 30954  [[:Talk:2021 Balochistan earthquake]] added to...  1633653280
# 30955  [[:Talk:2021 Balochistan earthquake]] added to...  1633653280
# 30956  [[:Talk:2021 Balochistan earthquake]] removed ...  1633653280
# 30957  [[:Talk:2021 Balochistan earthquake]] removed ...  1633653280
#
#                      user    bot  log_id log_type log_action log_params  \
# 30948  Prairie Astronomer  False     NaN      NaN        NaN        NaN
# 30954  Prairie Astronomer  False     NaN      NaN        NaN        NaN
# 30955  Prairie Astronomer  False     NaN      NaN        NaN        NaN
# 30956  Prairie Astronomer  False     NaN      NaN        NaN        NaN
# 30957  Prairie Astronomer  False     NaN      NaN        NaN        NaN
#
#       log_action_comment                server_url       server_name  \
# 30948                NaN  https://en.wikipedia.org  en.wikipedia.org
# 30954                NaN  https://en.wikipedia.org  en.wikipedia.org
# 30955                NaN  https://en.wikipedia.org  en.wikipedia.org
# 30956                NaN  https://en.wikipedia.org  en.wikipedia.org
# 30957                NaN  https://en.wikipedia.org  en.wikipedia.org
#
#       server_script_path    wiki  \
# 30948                 /w  enwiki
# 30954                 /w  enwiki
# 30955                 /w  enwiki
# 30956                 /w  enwiki
# 30957                 /w  enwiki
#
#                                            parsedcomment            id  minor  \
# 30948  Assessment: banner shell, Disaster management ...  1.430713e+09  False
# 30954  <a href="/wiki/Talk:2021_Balochistan_earthquak...  1.430713e+09    NaN
# 30955  <a href="/wiki/Talk:2021_Balochistan_earthquak...  1.430713e+09    NaN
# 30956  <a href="/wiki/Talk:2021_Balochistan_earthquak...  1.430713e+09    NaN
# 30957  <a href="/wiki/Talk:2021_Balochistan_earthquak...  1.430713e+09    NaN
#
#       patrolled                    length  \
# 30948       NaN  {'old': 230, 'new': 293}
# 30954       NaN                       NaN
# 30955       NaN                       NaN
# 30956       NaN                       NaN
# 30957       NaN                       NaN
#
#                                      revision    timestamp_parsed
# 30948  {'old': 1048758694, 'new': 1048790189} 2021-10-08 03:34:40
# 30954                                     NaN 2021-10-08 03:34:40
# 30955                                     NaN 2021-10-08 03:34:40
# 30956                                     NaN 2021-10-08 03:34:40
# 30957                                     NaN 2021-10-08 03:34:40

# %% [markdown]
# ## Change type analysis

# %%
df.type.value_counts()
# Out:
# edit          19111
# categorize     9958
# log            5394
# new            1535
# 142              15
# Name: type, dtype: int64

# %%
df[['type', 'bot', 'minor']].value_counts()
# Out:
# type  bot    minor
# edit  False  False    12118
#       True   False     4161
#       False  True      2226
# new   False  False     1233
# edit  True   True       606
# new   True   False      302
# dtype: int64

# %%
df_edits = df[df.type == 'edit']
df_edits.head(2)
# Out:
#                          $schema  \
# 1  /mediawiki/recentchange/1.0.0
# 2  /mediawiki/recentchange/1.0.0
#
#                                                 meta  type  namespace  \
# 1  {'uri': 'https://www.wikidata.org/wiki/Q108828...  edit          0
# 2  {'uri': 'https://ca.wikipedia.org/wiki/Tiriy%C...  edit          0
#
#         title                                            comment   timestamp  \
# 1  Q108828321  /* wbsetreference-add:2| */ [[Property:P26]]: ...  1633640647
# 2      Tiriyó                                    /* Dialectes */  1633640646
#
#           user    bot  log_id log_type log_action log_params  \
# 1  Quesotiotyo  False     NaN      NaN        NaN        NaN
# 2     Walden69  False     NaN      NaN        NaN        NaN
#
#   log_action_comment                server_url       server_name  \
# 1                NaN  https://www.wikidata.org  www.wikidata.org
# 2                NaN  https://ca.wikipedia.org  ca.wikipedia.org
#
#   server_script_path          wiki  \
# 1                 /w  wikidatawiki
# 2                 /w        cawiki
#
#                                        parsedcomment            id  minor  \
# 1  ‎<span dir="auto"><span class="autocomment">Ad...  1.556634e+09  False
# 2  <span dir="auto"><span class="autocomment"><a ...  1.041352e+08  False
#
#   patrolled                        length  \
# 1      True  {'old': 21609, 'new': 22654}
# 2      True  {'old': 10137, 'new': 11828}
#
#                                  revision    timestamp_parsed
# 1  {'old': 1509204168, 'new': 1509204170} 2021-10-08 00:04:07
# 2      {'old': 28378881, 'new': 28378955} 2021-10-08 00:04:06

# %% [markdown]
# ## Avg number of edits per user per timestamp (threshold of more than one change)

# %%
avg_changes_per_timestamp = df_edits[['user', 'timestamp']].value_counts().groupby('user').mean().reset_index()
avg_changes_per_timestamp.columns = ['user', 'changes_per_timestamp']
avg_changes_per_timestamp['bot'] = avg_changes_per_timestamp.user.map(lambda x: gd_dict[x])

np.random.seed(42)

# avg_changes_per_timestamp = avg_changes_per_timestamp[avg_changes_per_timestamp.changes_per_timestamp > 1.]

num = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].shape[0]
print(f'There are {num} bots')

bot_sample_df = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].sample(num)
not_bot_sample_df = avg_changes_per_timestamp[~avg_changes_per_timestamp.bot].sample(num)

# sample_df = pd.concat([bot_sample_df, not_bot_sample_df])
sample_df = avg_changes_per_timestamp[avg_changes_per_timestamp.changes_per_timestamp > 1.]

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes_per_timestamp:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user'), alt.Tooltip('changes_per_timestamp:Q')]
).properties(
    width = 600,
    height = 400,
    title = 'Number of changes by user per timestamp with more than 1 change'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [
        alt.Tooltip('count()', title='No of users'), 
        alt.Tooltip('bot')
    ]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart_counts | chart_bots
# Out:
# There are 46 bots
# alt.HConcatChart(...)

# %%
df_edits[df_edits.user == 'Jamc2']
# Out:
#                            $schema  \
# 145  /mediawiki/recentchange/1.0.0
# 146  /mediawiki/recentchange/1.0.0
# 147  /mediawiki/recentchange/1.0.0
# 149  /mediawiki/recentchange/1.0.0
# 153  /mediawiki/recentchange/1.0.0
# 155  /mediawiki/recentchange/1.0.0
# 156  /mediawiki/recentchange/1.0.0
# 162  /mediawiki/recentchange/1.0.0
#
#                                                   meta  type  namespace  \
# 145  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 146  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 147  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 149  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 153  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 155  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 156  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 162  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
#
#                                                  title  \
# 145  File:Bridge piers of the old Border Counties R...
# 146  File:Bridge pier of the old Border Counties Ra...
# 147  File:Bridge pier of the old Border Counties Ra...
# 149  File:Bridge piers of the old Border Counties R...
# 153  File:Bridge carrying the A69 over the River Ty...
# 155  File:Bridge piers of the old Border Counties R...
# 156  File:Bridge piers of the old Border Counties R...
# 162  File:Bridge carrying the A69 over the River Ty...
#
#                                                comment   timestamp   user  \
# 145  Copying from [[Category:United Kingdom photogr...  1633640682  Jamc2
# 146  Copying from [[Category:United Kingdom photogr...  1633640682  Jamc2
# 147  Copying from [[Category:United Kingdom photogr...  1633640682  Jamc2
# 149  Copying from [[Category:United Kingdom photogr...  1633640682  Jamc2
# 153  Copying from [[Category:United Kingdom photogr...  1633640682  Jamc2
# 155  Copying from [[Category:United Kingdom photogr...  1633640682  Jamc2
# 156  Copying from [[Category:United Kingdom photogr...  1633640682  Jamc2
# 162  Copying from [[Category:United Kingdom photogr...  1633640682  Jamc2
#
#        bot  log_id log_type log_action log_params log_action_comment  \
# 145  False     NaN      NaN        NaN        NaN                NaN
# 146  False     NaN      NaN        NaN        NaN                NaN
# 147  False     NaN      NaN        NaN        NaN                NaN
# 149  False     NaN      NaN        NaN        NaN                NaN
# 153  False     NaN      NaN        NaN        NaN                NaN
# 155  False     NaN      NaN        NaN        NaN                NaN
# 156  False     NaN      NaN        NaN        NaN                NaN
# 162  False     NaN      NaN        NaN        NaN                NaN
#
#                         server_url            server_name server_script_path  \
# 145  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 146  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 147  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 149  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 153  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 155  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 156  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 162  https://commons.wikimedia.org  commons.wikimedia.org                 /w
#
#             wiki                                      parsedcomment  \
# 145  commonswiki  Copying from <a href="/wiki/Category:United_Ki...
# 146  commonswiki  Copying from <a href="/wiki/Category:United_Ki...
# 147  commonswiki  Copying from <a href="/wiki/Category:United_Ki...
# 149  commonswiki  Copying from <a href="/wiki/Category:United_Ki...
# 153  commonswiki  Copying from <a href="/wiki/Category:United_Ki...
# 155  commonswiki  Copying from <a href="/wiki/Category:United_Ki...
# 156  commonswiki  Copying from <a href="/wiki/Category:United_Ki...
# 162  commonswiki  Copying from <a href="/wiki/Category:United_Ki...
#
#                id minor patrolled                      length  \
# 145  1.784971e+09  True      True  {'old': 6522, 'new': 6567}
# 146  1.784971e+09  True      True  {'old': 6701, 'new': 6746}
# 147  1.784971e+09  True      True  {'old': 6480, 'new': 6525}
# 149  1.784971e+09  True      True  {'old': 6761, 'new': 6806}
# 153  1.784971e+09  True      True  {'old': 6465, 'new': 6510}
# 155  1.784971e+09  True      True  {'old': 6736, 'new': 6781}
# 156  1.784971e+09  True      True  {'old': 6522, 'new': 6567}
# 162  1.784971e+09  True      True  {'old': 6456, 'new': 6501}
#
#                                  revision    timestamp_parsed
# 145  {'old': 538920554, 'new': 596618286} 2021-10-08 00:04:42
# 146  {'old': 538920663, 'new': 596618279} 2021-10-08 00:04:42
# 147  {'old': 538920543, 'new': 596618281} 2021-10-08 00:04:42
# 149  {'old': 538920542, 'new': 596618289} 2021-10-08 00:04:42
# 153  {'old': 539055128, 'new': 596618278} 2021-10-08 00:04:42
# 155  {'old': 538920545, 'new': 596618287} 2021-10-08 00:04:42
# 156  {'old': 538920552, 'new': 596618288} 2021-10-08 00:04:42
# 162  {'old': 539055132, 'new': 596618285} 2021-10-08 00:04:42

# %%
sample_df[['changes_per_timestamp', 'bot']].groupby('bot').mean()
# Out:
#        changes_per_timestamp
# bot
# False               1.095276
# True                1.163400

# %%
sample_df.head()
# Out:
#                   user  changes_per_timestamp   bot
# 1233          FuzzyBot               1.637255  True
# 858          AnomieBOT               1.003300  True
# 1872         RottenBot               1.000939  True
# 1973  SteinsplitterBot               1.169811  True
# 943     BotMultichillT               1.048507  True

# %%
temp = df_edits[['user', 'timestamp', 'bot']].value_counts().groupby('user').max().reset_index()
temp[temp.user == 'Raugeier']
# Out:
#           user   0
# 1823  Raugeier  22

# %%
df_edits[(df_edits.user == 'Raugeier')&(df_edits.timestamp == 1633642165)]
# Out:
#                             $schema  \
# 4005  /mediawiki/recentchange/1.0.0
# 4006  /mediawiki/recentchange/1.0.0
# 4007  /mediawiki/recentchange/1.0.0
# 4008  /mediawiki/recentchange/1.0.0
# 4009  /mediawiki/recentchange/1.0.0
# 4010  /mediawiki/recentchange/1.0.0
# 4011  /mediawiki/recentchange/1.0.0
# 4012  /mediawiki/recentchange/1.0.0
# 4013  /mediawiki/recentchange/1.0.0
# 4015  /mediawiki/recentchange/1.0.0
# 4018  /mediawiki/recentchange/1.0.0
# 4019  /mediawiki/recentchange/1.0.0
# 4021  /mediawiki/recentchange/1.0.0
# 4022  /mediawiki/recentchange/1.0.0
# 4023  /mediawiki/recentchange/1.0.0
# 4025  /mediawiki/recentchange/1.0.0
# 4029  /mediawiki/recentchange/1.0.0
# 4030  /mediawiki/recentchange/1.0.0
# 4032  /mediawiki/recentchange/1.0.0
# 4039  /mediawiki/recentchange/1.0.0
# 4045  /mediawiki/recentchange/1.0.0
# 4047  /mediawiki/recentchange/1.0.0
#
#                                                    meta  type  namespace  \
# 4005  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4006  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4007  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4008  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4009  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4010  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4011  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4012  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4013  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4015  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4018  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4019  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4021  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4022  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4023  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4025  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4029  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4030  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4032  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4039  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4045  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
# 4047  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  edit          6
#
#                                                title  \
# 4005    File:St. Nicolai in Gödringen -3351-Pano.jpg
# 4006     File:St. Nicolai in Gödringen-4624-Pano.jpg
# 4007          File:St. Nicolai in Gödringen-3384.jpg
# 4008          File:St. Nicolai in Gödringen-3404.jpg
# 4009          File:St. Nicolai in Gödringen-4620.jpg
# 4010          File:St. Nicolai in Gödringen-3362.jpg
# 4011          File:St. Nicolai in Gödringen-3259.jpg
# 4012          File:St. Nicolai in Gödringen-3300.jpg
# 4013          File:St. Nicolai in Gödringen-3327.jpg
# 4015  File:Ehemaliges Parrhaus (Gödringen) -3409.jpg
# 4018          File:St. Nicolai in Gödringen-3315.jpg
# 4019          File:St. Nicolai in Gödringen-3312.jpg
# 4021     File:St. Nicolai in Gödringen-4612 Pano.jpg
# 4022          File:St. Nicolai in Gödringen-3333.jpg
# 4023          File:St. Nicolai in Gödringen-3321.jpg
# 4025          File:St. Nicolai in Gödringen-3263.jpg
# 4029          File:St. Nicolai in Gödringen-3282.jpg
# 4030          File:St. Nicolai in Gödringen-3291.jpg
# 4032          File:St. Nicolai in Gödringen-3369.jpg
# 4039          File:St. Nicolai in Gödringen-4611.jpg
# 4045          File:St. Nicolai in Gödringen-3255.jpg
# 4047          File:St. Nicolai in Gödringen-4608.jpg
#
#                                                 comment   timestamp      user  \
# 4005  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4006  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4007  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4008  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4009  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4010  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4011  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4012  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4013  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4015  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4018  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4019  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4021  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4022  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4023  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4025  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4029  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4030  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4032  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4039  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4045  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4047  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
#
#         bot  log_id log_type log_action log_params log_action_comment  \
# 4005  False     NaN      NaN        NaN        NaN                NaN
# 4006  False     NaN      NaN        NaN        NaN                NaN
# 4007  False     NaN      NaN        NaN        NaN                NaN
# 4008  False     NaN      NaN        NaN        NaN                NaN
# 4009  False     NaN      NaN        NaN        NaN                NaN
# 4010  False     NaN      NaN        NaN        NaN                NaN
# 4011  False     NaN      NaN        NaN        NaN                NaN
# 4012  False     NaN      NaN        NaN        NaN                NaN
# 4013  False     NaN      NaN        NaN        NaN                NaN
# 4015  False     NaN      NaN        NaN        NaN                NaN
# 4018  False     NaN      NaN        NaN        NaN                NaN
# 4019  False     NaN      NaN        NaN        NaN                NaN
# 4021  False     NaN      NaN        NaN        NaN                NaN
# 4022  False     NaN      NaN        NaN        NaN                NaN
# 4023  False     NaN      NaN        NaN        NaN                NaN
# 4025  False     NaN      NaN        NaN        NaN                NaN
# 4029  False     NaN      NaN        NaN        NaN                NaN
# 4030  False     NaN      NaN        NaN        NaN                NaN
# 4032  False     NaN      NaN        NaN        NaN                NaN
# 4039  False     NaN      NaN        NaN        NaN                NaN
# 4045  False     NaN      NaN        NaN        NaN                NaN
# 4047  False     NaN      NaN        NaN        NaN                NaN
#
#                          server_url            server_name server_script_path  \
# 4005  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4006  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4007  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4008  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4009  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4010  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4011  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4012  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4013  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4015  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4018  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4019  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4021  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4022  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4023  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4025  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4029  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4030  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4032  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4039  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4045  https://commons.wikimedia.org  commons.wikimedia.org                 /w
# 4047  https://commons.wikimedia.org  commons.wikimedia.org                 /w
#
#              wiki                                      parsedcomment  \
# 4005  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4006  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4007  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4008  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4009  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4010  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4011  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4012  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4013  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4015  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4018  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4019  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4021  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4022  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4023  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4025  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4029  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4030  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4032  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4039  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4045  commonswiki  Removing from <a href="/wiki/Category:Images_f...
# 4047  commonswiki  Removing from <a href="/wiki/Category:Images_f...
#
#                 id minor patrolled                      length  \
# 4005  1.784986e+09  True      True  {'old': 4128, 'new': 4059}
# 4006  1.784986e+09  True      True  {'old': 2402, 'new': 2332}
# 4007  1.784986e+09  True      True  {'old': 2109, 'new': 2039}
# 4008  1.784986e+09  True      True  {'old': 2152, 'new': 2082}
# 4009  1.784986e+09  True      True  {'old': 2183, 'new': 2113}
# 4010  1.784986e+09  True      True  {'old': 2155, 'new': 2085}
# 4011  1.784986e+09  True      True  {'old': 2154, 'new': 2084}
# 4012  1.784986e+09  True      True  {'old': 2161, 'new': 2091}
# 4013  1.784986e+09  True      True  {'old': 2153, 'new': 2083}
# 4015  1.784986e+09  True      True  {'old': 3813, 'new': 3743}
# 4018  1.784986e+09  True      True  {'old': 3766, 'new': 3696}
# 4019  1.784986e+09  True      True  {'old': 2161, 'new': 2091}
# 4021  1.784986e+09  True      True  {'old': 2175, 'new': 2105}
# 4022  1.784986e+09  True      True  {'old': 2153, 'new': 2083}
# 4023  1.784986e+09  True      True  {'old': 2152, 'new': 2082}
# 4025  1.784986e+09  True      True  {'old': 2160, 'new': 2090}
# 4029  1.784986e+09  True      True  {'old': 2156, 'new': 2086}
# 4030  1.784986e+09  True      True  {'old': 2155, 'new': 2085}
# 4032  1.784986e+09  True      True  {'old': 2103, 'new': 2033}
# 4039  1.784986e+09  True      True  {'old': 3780, 'new': 3710}
# 4045  1.784986e+09  True      True  {'old': 2226, 'new': 2156}
# 4047  1.784986e+09  True      True  {'old': 2226, 'new': 2156}
#
#                                   revision    timestamp_parsed
# 4005  {'old': 593273218, 'new': 596627307} 2021-10-08 00:29:25
# 4006  {'old': 590529766, 'new': 596627314} 2021-10-08 00:29:25
# 4007  {'old': 593271182, 'new': 596627319} 2021-10-08 00:29:25
# 4008  {'old': 593271297, 'new': 596627308} 2021-10-08 00:29:25
# 4009  {'old': 591791253, 'new': 596627316} 2021-10-08 00:29:25
# 4010  {'old': 590529927, 'new': 596627317} 2021-10-08 00:29:25
# 4011  {'old': 593270776, 'new': 596627310} 2021-10-08 00:29:25
# 4012  {'old': 590530180, 'new': 596627312} 2021-10-08 00:29:25
# 4013  {'old': 590528880, 'new': 596627324} 2021-10-08 00:29:25
# 4015  {'old': 592631375, 'new': 596627325} 2021-10-08 00:29:25
# 4018  {'old': 592631986, 'new': 596627321} 2021-10-08 00:29:25
# 4019  {'old': 590530117, 'new': 596627327} 2021-10-08 00:29:25
# 4021  {'old': 590529722, 'new': 596627323} 2021-10-08 00:29:25
# 4022  {'old': 593271114, 'new': 596627326} 2021-10-08 00:29:25
# 4023  {'old': 593271041, 'new': 596627322} 2021-10-08 00:29:25
# 4025  {'old': 593270847, 'new': 596627306} 2021-10-08 00:29:25
# 4029  {'old': 593270917, 'new': 596627328} 2021-10-08 00:29:25
# 4030  {'old': 590529981, 'new': 596627311} 2021-10-08 00:29:25
# 4032  {'old': 590528598, 'new': 596627309} 2021-10-08 00:29:25
# 4039  {'old': 592631992, 'new': 596627320} 2021-10-08 00:29:25
# 4045  {'old': 593273138, 'new': 596627315} 2021-10-08 00:29:25
# 4047  {'old': 593271409, 'new': 596627318} 2021-10-08 00:29:25

# %%
from datetime import datetime

df_edits['timestamp_parsed'] = df_edits.timestamp.map(lambda x: datetime.fromtimestamp(x))

avg_changes_per_timestamp = df_edits[['user', 'timestamp']].value_counts().groupby('user').max().reset_index()
avg_changes_per_timestamp.columns = ['user', 'changes_per_timestamp']
avg_changes_per_timestamp['bot'] = avg_changes_per_timestamp.user.map(lambda x: gd_dict[x])

np.random.seed(42)

avg_changes_per_timestamp = avg_changes_per_timestamp[avg_changes_per_timestamp.changes_per_timestamp > 1.]

num = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].shape[0]
print(f'There are {num} bots')

bot_sample_df = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].sample(num)
not_bot_sample_df = avg_changes_per_timestamp[~avg_changes_per_timestamp.bot].sample(num)

sample_df = pd.concat([bot_sample_df, not_bot_sample_df])

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes_per_timestamp:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user'), alt.Tooltip('changes_per_timestamp:Q')]
).properties(
    width = 600,
    height = 400,
    title = 'Max of changes by user per timestamp with more than 1 change'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [
        alt.Tooltip('count()', title='No of users'), 
        alt.Tooltip('bot')
    ]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart_counts | chart_bots
# Out:
# /tmp/ipykernel_332576/885551162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_edits['timestamp_parsed'] = df_edits.timestamp.map(lambda x: datetime.fromtimestamp(x))
# There are 11 bots
# alt.HConcatChart(...)

# %%
avg_changes_per_timestamp[avg_changes_per_timestamp.user == 'Raugeier']
# Out:
#           user  changes_per_timestamp    bot
# 1823  Raugeier                     22  False
