# %% [markdown]
# # Data collection

# %%
import altair as alt
import json
import matplotlib.pyplot as plt
import os
import pandas as pd
import time
from sseclient import SSEClient as EventSource

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
url = 'https://stream.wikimedia.org/v2/stream/recentchange'
dataset = []
users = set()
events_counter = 0
time_threshold = 5.0
t_0  = time.time()

for event in EventSource(url): # start streaming
    if event.event == 'message':
        try:
            change = json.loads(event.data)
        except ValueError:
            continue
            
        events_counter += 1

        users.add(change['user'])
        user_hash = hash(change['user'])
        if user_hash % 10 < 2:
            dataset.append(change)
            
        if (time.time() - t_0)//60 > time_threshold:
            break
            
df = pd.DataFrame(dataset)
# df.to_csv(f'dataset_{t_0}.tsv')

# %%
len(dataset), events_counter, len(dataset)*100/events_counter
# Out:
# (2739, 9477, 28.901551123773345)

# %%
len(dataset), events_counter, len(set(dataset['user']))*100/events_counter

# %%
dfs = []
for f_ in ['dataset.tsv',
 'dataset_1633640647.5015893.tsv',
 'dataset_1633702613.0484471.tsv',
 'dataset_1633636846.3666255.tsv',
 'morning_data.csv']:
    dfs.append(pd.read_csv('data/' + f_))
    
all_data = pd.concat(dfs)
all_data.head(2)
# Out:
#    Unnamed: 0                        $schema  \
# 0           0  /mediawiki/recentchange/1.0.0
# 1           1  /mediawiki/recentchange/1.0.0
# 2           2  /mediawiki/recentchange/1.0.0
# 3           3  /mediawiki/recentchange/1.0.0
# 4           4  /mediawiki/recentchange/1.0.0
#
#                                                 meta            id  type  \
# 0  {'uri': 'https://www.wikidata.org/wiki/Q108828...  1.556609e+09  edit
# 1  {'uri': 'https://www.wikidata.org/wiki/Q175855...  1.556609e+09  edit
# 2  {'uri': 'https://www.wikidata.org/wiki/Q302623...  1.556609e+09  edit
# 3  {'uri': 'https://www.wikidata.org/wiki/Q108828...  1.556609e+09  edit
# 4  {'uri': 'https://www.wikidata.org/wiki/Q302623...  1.556609e+09  edit
#
#    namespace       title                                            comment  \
# 0          0  Q108828195  /* wbsetreference-add:2| */ [[Property:P570]]:...
# 1          0   Q17585531  /* wbsetreference-set:2| */ [[Property:P141]]:...
# 2          0   Q30262345  /* wbsetreference-set:2| */ [[Property:P3016]]...
# 3          0  Q108828195  /* wbsetreference-add:2| */ [[Property:P20]]: ...
# 4          0   Q30262346  /* wbsetreference-set:2| */ [[Property:P3016]]...
#
#     timestamp         user    bot  minor patrolled  \
# 0  1633634790  Quesotiotyo  False  False      True
# 1  1633634789     SuccuBot   True  False      True
# 2  1633634791        KrBot   True  False      True
# 3  1633634792  Quesotiotyo  False  False      True
# 4  1633634792        KrBot   True  False      True
#
#                          length                                revision  \
# 0  {'old': 28649, 'new': 29712}  {'old': 1509178938, 'new': 1509178965}
# 1  {'old': 16134, 'new': 16134}  {'old': 1458793714, 'new': 1509178961}
# 2  {'old': 11328, 'new': 11328}  {'old': 1304488366, 'new': 1509178977}
# 3  {'old': 29712, 'new': 30775}  {'old': 1509178965, 'new': 1509178984}
# 4  {'old': 15657, 'new': 15657}  {'old': 1304474435, 'new': 1509178983}
#
#                  server_url       server_name server_script_path  \
# 0  https://www.wikidata.org  www.wikidata.org                 /w
# 1  https://www.wikidata.org  www.wikidata.org                 /w
# 2  https://www.wikidata.org  www.wikidata.org                 /w
# 3  https://www.wikidata.org  www.wikidata.org                 /w
# 4  https://www.wikidata.org  www.wikidata.org                 /w
#
#            wiki                                      parsedcomment  log_id  \
# 0  wikidatawiki  ‎<span dir="auto"><span class="autocomment">Ad...     NaN
# 1  wikidatawiki  ‎<span dir="auto"><span class="autocomment">Fu...     NaN
# 2  wikidatawiki  ‎<span dir="auto"><span class="autocomment">Из...     NaN
# 3  wikidatawiki  ‎<span dir="auto"><span class="autocomment">Ad...     NaN
# 4  wikidatawiki  ‎<span dir="auto"><span class="autocomment">Из...     NaN
#
#   log_type log_action log_params log_action_comment
# 0      NaN        NaN        NaN                NaN
# 1      NaN        NaN        NaN                NaN
# 2      NaN        NaN        NaN                NaN
# 3      NaN        NaN        NaN                NaN
# 4      NaN        NaN        NaN                NaN

# %%
all_data.shape
# Out:
# (120467, 25)

# %%
len(all_data.user.unique())
# Out:
# 7109

# %%
all_data.bot.value_counts()
# Out:
# False    75046
# True     45421
# Name: bot, dtype: int64

# %%
len(all_data[all_data.bot].user.unique())
# Out:
# 208

# %%
all_data.to_csv('all_data.tsv', sep='\t')

# %%
df = all_data.copy()

# %% [markdown]
# # Data exploration

# %% [markdown]
# ## Number of changes done by user

# %%
# ! pip install altair
import altair as alt
import numpy as np
import pandas as pd

gd_dict = {row['user']: row['bot'] for _, row in df.iterrows()}
df_counts = df.user.value_counts().reset_index()
df_counts.columns = ['user', 'changes']
df_counts['bot'] = df_counts.user.map(lambda x: gd_dict[x])
df_counts.head()

np.random.seed(42)
sample_df = df_counts.sample(min(df_counts.shape[0], 400))

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes:Q'),
    color = alt.Color('bot:N'),
    tooltip = [
        alt.Tooltip('user'), 
        alt.Tooltip('changes')
    ]
).properties(
    width = 600,
    height = 400,
    title = 'Number of changes by user'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [alt.Tooltip('count()', title='No of users')]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart_counts | chart_bots
# Out:
# alt.HConcatChart(...)

# %%
df[(df.user == 'ST47ProxyBot')].head()
# Out:
#                           $schema  \
# 3   /mediawiki/recentchange/1.0.0
# 4   /mediawiki/recentchange/1.0.0
# 5   /mediawiki/recentchange/1.0.0
# 9   /mediawiki/recentchange/1.0.0
# 12  /mediawiki/recentchange/1.0.0
#
#                                                  meta            id type  \
# 3   {'uri': 'https://en.wikipedia.org/wiki/User:41...  1.430871e+09  log
# 4   {'uri': 'https://en.wikipedia.org/wiki/User:41...  1.430871e+09  log
# 5   {'uri': 'https://en.wikipedia.org/wiki/User:12...  1.430871e+09  log
# 9   {'uri': 'https://en.wikipedia.org/wiki/User:11...  1.430871e+09  log
# 12  {'uri': 'https://en.wikipedia.org/wiki/User:41...  1.430871e+09  log
#
#     namespace                 title  \
# 3           2    User:41.217.27.208
# 4           2     User:41.68.97.100
# 5           2  User:123.231.107.212
# 9           2  User:119.160.103.155
# 12          2      User:41.107.0.80
#
#                                               comment   timestamp  \
# 3   {{blocked p2p proxy|ip=41.217.27.208|isp=Used ...  1633699044
# 4   {{blocked p2p proxy|ip=41.68.97.100|isp=Vodafo...  1633699044
# 5   {{blocked p2p proxy|ip=123.231.107.212|isp=MTT...  1633699045
# 9   {{blocked p2p proxy|ip=119.160.103.155|isp=Mob...  1633699045
# 12  {{blocked p2p proxy|ip=41.107.0.80|isp=Residen...  1633699045
#
#             user   bot minor patrolled length revision  \
# 3   ST47ProxyBot  True   NaN       NaN    NaN      NaN
# 4   ST47ProxyBot  True   NaN       NaN    NaN      NaN
# 5   ST47ProxyBot  True   NaN       NaN    NaN      NaN
# 9   ST47ProxyBot  True   NaN       NaN    NaN      NaN
# 12  ST47ProxyBot  True   NaN       NaN    NaN      NaN
#
#                   server_url       server_name server_script_path    wiki  \
# 3   https://en.wikipedia.org  en.wikipedia.org                 /w  enwiki
# 4   https://en.wikipedia.org  en.wikipedia.org                 /w  enwiki
# 5   https://en.wikipedia.org  en.wikipedia.org                 /w  enwiki
# 9   https://en.wikipedia.org  en.wikipedia.org                 /w  enwiki
# 12  https://en.wikipedia.org  en.wikipedia.org                 /w  enwiki
#
#                                         parsedcomment       log_id log_type  \
# 3   {{blocked p2p proxy|ip=41.217.27.208|isp=Used ...  122507192.0    block
# 4   {{blocked p2p proxy|ip=41.68.97.100|isp=Vodafo...  122507191.0    block
# 5   {{blocked p2p proxy|ip=123.231.107.212|isp=MTT...  122507193.0    block
# 9   {{blocked p2p proxy|ip=119.160.103.155|isp=Mob...  122507196.0    block
# 12  {{blocked p2p proxy|ip=41.107.0.80|isp=Residen...  122507194.0    block
#
#    log_action                                         log_params  \
# 3       block  {'duration': '71 hours', 'flags': 'nocreate', ...
# 4       block  {'duration': '71 hours', 'flags': 'nocreate', ...
# 5       block  {'duration': '71 hours', 'flags': 'nocreate', ...
# 9       block  {'duration': '71 hours', 'flags': 'anononly,no...
# 12      block  {'duration': '71 hours', 'flags': 'nocreate', ...
#
#                                    log_action_comment    timestamp_parsed
# 3   blocked User:41.217.27.208 (account creation b... 2021-10-08 16:17:24
# 4   blocked User:41.68.97.100 (account creation bl... 2021-10-08 16:17:24
# 5   blocked User:123.231.107.212 (account creation... 2021-10-08 16:17:25
# 9   blocked User:119.160.103.155 (anon. only, acco... 2021-10-08 16:17:25
# 12  blocked User:41.107.0.80 (account creation blo... 2021-10-08 16:17:25

# %% [markdown]
# ## Avg number of changes done by user per timestamp

# %%
from datetime import datetime

df['timestamp_parsed'] = df.timestamp.map(lambda x: datetime.fromtimestamp(x))

avg_changes_per_timestamp = df[['user', 'timestamp']].value_counts().groupby('user').mean().reset_index()
avg_changes_per_timestamp.columns = ['user', 'changes_per_timestamp']
avg_changes_per_timestamp['bot'] = avg_changes_per_timestamp.user.map(lambda x: gd_dict[x])

np.random.seed(42)
sample_df = avg_changes_per_timestamp.sample(min(avg_changes_per_timestamp.shape[0], 400))

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    
    y = alt.Y('changes_per_timestamp:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user'), alt.Tooltip('changes_per_timestamp:Q')]
).properties(
    width = 600,
    height = 400,
    title = 'Number of changes by user per timestamp'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [alt.Tooltip('count()', title='No of users')]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart_counts | chart_bots
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ## Avg number of changes done by user per timestamp (balanced by bot/not bot)

# %%
from datetime import datetime

df['timestamp_parsed'] = df.timestamp.map(lambda x: datetime.fromtimestamp(x))

avg_changes_per_timestamp = df[['user', 'timestamp']].value_counts().groupby('user').mean().reset_index()
avg_changes_per_timestamp.columns = ['user', 'changes_per_timestamp']
avg_changes_per_timestamp['bot'] = avg_changes_per_timestamp.user.map(lambda x: gd_dict[x])

np.random.seed(42)
num = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].shape[0]
bot_sample_df = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].sample(num)
not_bot_sample_df = avg_changes_per_timestamp[~avg_changes_per_timestamp.bot].sample(num)

sample_df = pd.concat([bot_sample_df, not_bot_sample_df])

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes_per_timestamp:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user'), alt.Tooltip('changes_per_timestamp:Q')]
).properties(
    width = 600,
    height = 400,
    title = 'Number of changes by user per timestamp'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [
        alt.Tooltip('count()', title='No of users'), 
        alt.Tooltip('bot')
    ]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart_counts | chart_bots
# Out:
# alt.HConcatChart(...)

# %%
sample_df[['changes_per_timestamp', 'bot']][sample_df.changes_per_timestamp > 1].groupby('bot').mean()
# Out:
#        changes_per_timestamp
# bot
# False               2.572370
# True                2.163909

# %% [markdown]
# ## Avg number of changes done by user per timestamp (balanced by bot/not bot and with more than 1 change)

# %%
from datetime import datetime

df['timestamp_parsed'] = df.timestamp.map(lambda x: datetime.fromtimestamp(x))

avg_changes_per_timestamp = df[['user', 'timestamp']].value_counts().groupby('user').mean().reset_index()
avg_changes_per_timestamp.columns = ['user', 'changes_per_timestamp']
avg_changes_per_timestamp['bot'] = avg_changes_per_timestamp.user.map(lambda x: gd_dict[x])

np.random.seed(42)

avg_changes_per_timestamp = avg_changes_per_timestamp[avg_changes_per_timestamp.changes_per_timestamp > 1.]

num = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].shape[0]
print(f'There are {num} bots')

bot_sample_df = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].sample(num)
not_bot_sample_df = avg_changes_per_timestamp[~avg_changes_per_timestamp.bot].sample(num)

sample_df = pd.concat([bot_sample_df, not_bot_sample_df])

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes_per_timestamp:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user'), alt.Tooltip('changes_per_timestamp:Q')]
).properties(
    width = 600,
    height = 400,
    title = 'Number of changes by user per timestamp with more than 1 change'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [
        alt.Tooltip('count()', title='No of users'), 
        alt.Tooltip('bot')
    ]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart_counts | chart_bots
# Out:
# There are 76 bots
# alt.HConcatChart(...)

# %%
sample_df[['changes_per_timestamp', 'bot']].groupby('bot').mean()
# Out:
#        changes_per_timestamp
# bot
# False               2.738688
# True                2.163909

# %%
df[(df.user == 'Phediuk')&(df.timestamp == 1633643510)]
# Out:
#       Unnamed: 0                        $schema  \
# 8066        8066  /mediawiki/recentchange/1.0.0
# 8069        8069  /mediawiki/recentchange/1.0.0
# 8070        8070  /mediawiki/recentchange/1.0.0
# 8072        8072  /mediawiki/recentchange/1.0.0
#
#                                                    meta            id  \
# 8066  {'uri': 'https://en.wikipedia.org/wiki/Day_of_...  1.430680e+09
# 8069  {'uri': 'https://en.wikipedia.org/wiki/Categor...  1.430680e+09
# 8070  {'uri': 'https://en.wikipedia.org/wiki/Categor...  1.430680e+09
# 8072  {'uri': 'https://en.wikipedia.org/wiki/Categor...  1.430680e+09
#
#             type  namespace  \
# 8066        edit          0
# 8069  categorize         14
# 8070  categorize         14
# 8072  categorize         14
#
#                                                   title  \
# 8066                               Day of the Figurines
# 8069                          Category:2005 video games
# 8070        Category:Massively multiplayer online games
# 8072  Category:Video games developed in the United K...
#
#                                                 comment   timestamp     user  \
# 8066                                                NaN  1633643510  Phediuk
# 8069  [[:Day of the Figurines]] added to category, [...  1633643510  Phediuk
# 8070  [[:Day of the Figurines]] added to category, [...  1633643510  Phediuk
# 8072  [[:Day of the Figurines]] added to category, [...  1633643510  Phediuk
#
#         bot  minor patrolled                      length  \
# 8066  False  False       NaN  {'old': 2292, 'new': 2426}
# 8069  False    NaN       NaN                         NaN
# 8070  False    NaN       NaN                         NaN
# 8072  False    NaN       NaN                         NaN
#
#                                    revision                server_url  \
# 8066  {'old': 987420945, 'new': 1048773585}  https://en.wikipedia.org
# 8069                                    NaN  https://en.wikipedia.org
# 8070                                    NaN  https://en.wikipedia.org
# 8072                                    NaN  https://en.wikipedia.org
#
#            server_name server_script_path    wiki  \
# 8066  en.wikipedia.org                 /w  enwiki
# 8069  en.wikipedia.org                 /w  enwiki
# 8070  en.wikipedia.org                 /w  enwiki
# 8072  en.wikipedia.org                 /w  enwiki
#
#                                           parsedcomment  log_id log_type  \
# 8066                                                NaN     NaN      NaN
# 8069  <a href="/wiki/Day_of_the_Figurines" title="Da...     NaN      NaN
# 8070  <a href="/wiki/Day_of_the_Figurines" title="Da...     NaN      NaN
# 8072  <a href="/wiki/Day_of_the_Figurines" title="Da...     NaN      NaN
#
#      log_action log_params log_action_comment    timestamp_parsed
# 8066        NaN        NaN                NaN 2021-10-08 00:51:50
# 8069        NaN        NaN                NaN 2021-10-08 00:51:50
# 8070        NaN        NaN                NaN 2021-10-08 00:51:50
# 8072        NaN        NaN                NaN 2021-10-08 00:51:50

# %%
df[(df.user == 'Prairie Astronomer')&(df.timestamp == 1633653280)]
# Out:
#        Unnamed: 0                        $schema  \
# 30948       30948  /mediawiki/recentchange/1.0.0
# 30954       30954  /mediawiki/recentchange/1.0.0
# 30955       30955  /mediawiki/recentchange/1.0.0
# 30956       30956  /mediawiki/recentchange/1.0.0
# 30957       30957  /mediawiki/recentchange/1.0.0
#
#                                                     meta            id  \
# 30948  {'uri': 'https://en.wikipedia.org/wiki/Talk:20...  1.430713e+09
# 30954  {'uri': 'https://en.wikipedia.org/wiki/Categor...  1.430713e+09
# 30955  {'uri': 'https://en.wikipedia.org/wiki/Categor...  1.430713e+09
# 30956  {'uri': 'https://en.wikipedia.org/wiki/Categor...  1.430713e+09
# 30957  {'uri': 'https://en.wikipedia.org/wiki/Categor...  1.430713e+09
#
#              type  namespace  \
# 30948        edit          1
# 30954  categorize         14
# 30955  categorize         14
# 30956  categorize         14
# 30957  categorize         14
#
#                                                    title  \
# 30948                   Talk:2021 Balochistan earthquake
# 30954  Category:Mid-importance Disaster management ar...
# 30955          Category:Low-importance Pakistan articles
# 30956  Category:Unknown-importance Disaster managemen...
# 30957      Category:Unknown-importance Pakistan articles
#
#                                                  comment   timestamp  \
# 30948  Assessment: banner shell, Disaster management ...  1633653280
# 30954  [[:Talk:2021 Balochistan earthquake]] added to...  1633653280
# 30955  [[:Talk:2021 Balochistan earthquake]] added to...  1633653280
# 30956  [[:Talk:2021 Balochistan earthquake]] removed ...  1633653280
# 30957  [[:Talk:2021 Balochistan earthquake]] removed ...  1633653280
#
#                      user    bot  minor patrolled                    length  \
# 30948  Prairie Astronomer  False  False       NaN  {'old': 230, 'new': 293}
# 30954  Prairie Astronomer  False    NaN       NaN                       NaN
# 30955  Prairie Astronomer  False    NaN       NaN                       NaN
# 30956  Prairie Astronomer  False    NaN       NaN                       NaN
# 30957  Prairie Astronomer  False    NaN       NaN                       NaN
#
#                                      revision                server_url  \
# 30948  {'old': 1048758694, 'new': 1048790189}  https://en.wikipedia.org
# 30954                                     NaN  https://en.wikipedia.org
# 30955                                     NaN  https://en.wikipedia.org
# 30956                                     NaN  https://en.wikipedia.org
# 30957                                     NaN  https://en.wikipedia.org
#
#             server_name server_script_path    wiki  \
# 30948  en.wikipedia.org                 /w  enwiki
# 30954  en.wikipedia.org                 /w  enwiki
# 30955  en.wikipedia.org                 /w  enwiki
# 30956  en.wikipedia.org                 /w  enwiki
# 30957  en.wikipedia.org                 /w  enwiki
#
#                                            parsedcomment  log_id log_type  \
# 30948  Assessment: banner shell, Disaster management ...     NaN      NaN
# 30954  <a href="/wiki/Talk:2021_Balochistan_earthquak...     NaN      NaN
# 30955  <a href="/wiki/Talk:2021_Balochistan_earthquak...     NaN      NaN
# 30956  <a href="/wiki/Talk:2021_Balochistan_earthquak...     NaN      NaN
# 30957  <a href="/wiki/Talk:2021_Balochistan_earthquak...     NaN      NaN
#
#       log_action log_params log_action_comment    timestamp_parsed
# 30948        NaN        NaN                NaN 2021-10-08 03:34:40
# 30954        NaN        NaN                NaN 2021-10-08 03:34:40
# 30955        NaN        NaN                NaN 2021-10-08 03:34:40
# 30956        NaN        NaN                NaN 2021-10-08 03:34:40
# 30957        NaN        NaN                NaN 2021-10-08 03:34:40

# %% [markdown]
# ## Change type analysis

# %%
df.type.value_counts()
# Out:
# edit          75857
# categorize    29798
# log           11134
# new            3653
# 142              25
# Name: type, dtype: int64

# %%
df[['type', 'bot', 'minor']].value_counts()
# Out:
# type  bot    minor
# edit  False  False    34630
#       True   False    29800
#       False  True      6379
#       True   True      5048
# new   False  False     2762
#       True   False      891
# dtype: int64

# %%
df_edits = df[df.type == 'edit']
df_edits.head()
# Out:
#    Unnamed: 0                        $schema  \
# 0           0  /mediawiki/recentchange/1.0.0
# 1           1  /mediawiki/recentchange/1.0.0
# 2           2  /mediawiki/recentchange/1.0.0
# 3           3  /mediawiki/recentchange/1.0.0
# 4           4  /mediawiki/recentchange/1.0.0
#
#                                                 meta            id  type  \
# 0  {'uri': 'https://www.wikidata.org/wiki/Q108828...  1.556609e+09  edit
# 1  {'uri': 'https://www.wikidata.org/wiki/Q175855...  1.556609e+09  edit
# 2  {'uri': 'https://www.wikidata.org/wiki/Q302623...  1.556609e+09  edit
# 3  {'uri': 'https://www.wikidata.org/wiki/Q108828...  1.556609e+09  edit
# 4  {'uri': 'https://www.wikidata.org/wiki/Q302623...  1.556609e+09  edit
#
#    namespace       title                                            comment  \
# 0          0  Q108828195  /* wbsetreference-add:2| */ [[Property:P570]]:...
# 1          0   Q17585531  /* wbsetreference-set:2| */ [[Property:P141]]:...
# 2          0   Q30262345  /* wbsetreference-set:2| */ [[Property:P3016]]...
# 3          0  Q108828195  /* wbsetreference-add:2| */ [[Property:P20]]: ...
# 4          0   Q30262346  /* wbsetreference-set:2| */ [[Property:P3016]]...
#
#     timestamp         user    bot  minor patrolled  \
# 0  1633634790  Quesotiotyo  False  False      True
# 1  1633634789     SuccuBot   True  False      True
# 2  1633634791        KrBot   True  False      True
# 3  1633634792  Quesotiotyo  False  False      True
# 4  1633634792        KrBot   True  False      True
#
#                          length                                revision  \
# 0  {'old': 28649, 'new': 29712}  {'old': 1509178938, 'new': 1509178965}
# 1  {'old': 16134, 'new': 16134}  {'old': 1458793714, 'new': 1509178961}
# 2  {'old': 11328, 'new': 11328}  {'old': 1304488366, 'new': 1509178977}
# 3  {'old': 29712, 'new': 30775}  {'old': 1509178965, 'new': 1509178984}
# 4  {'old': 15657, 'new': 15657}  {'old': 1304474435, 'new': 1509178983}
#
#                  server_url       server_name server_script_path  \
# 0  https://www.wikidata.org  www.wikidata.org                 /w
# 1  https://www.wikidata.org  www.wikidata.org                 /w
# 2  https://www.wikidata.org  www.wikidata.org                 /w
# 3  https://www.wikidata.org  www.wikidata.org                 /w
# 4  https://www.wikidata.org  www.wikidata.org                 /w
#
#            wiki                                      parsedcomment  log_id  \
# 0  wikidatawiki  ‎<span dir="auto"><span class="autocomment">Ad...     NaN
# 1  wikidatawiki  ‎<span dir="auto"><span class="autocomment">Fu...     NaN
# 2  wikidatawiki  ‎<span dir="auto"><span class="autocomment">Из...     NaN
# 3  wikidatawiki  ‎<span dir="auto"><span class="autocomment">Ad...     NaN
# 4  wikidatawiki  ‎<span dir="auto"><span class="autocomment">Из...     NaN
#
#   log_type log_action log_params log_action_comment    timestamp_parsed
# 0      NaN        NaN        NaN                NaN 2021-10-07 22:26:30
# 1      NaN        NaN        NaN                NaN 2021-10-07 22:26:29
# 2      NaN        NaN        NaN                NaN 2021-10-07 22:26:31
# 3      NaN        NaN        NaN                NaN 2021-10-07 22:26:32
# 4      NaN        NaN        NaN                NaN 2021-10-07 22:26:32

# %%
# df_edits['timestamp_parsed'] = df_edits.timestamp.map(lambda x: datetime.fromtimestamp(x))

avg_changes_per_timestamp = df_edits[['user', 'timestamp']].value_counts().groupby('user').mean().reset_index()
avg_changes_per_timestamp.columns = ['user', 'changes_per_timestamp']
avg_changes_per_timestamp['bot'] = avg_changes_per_timestamp.user.map(lambda x: gd_dict[x])

np.random.seed(42)

avg_changes_per_timestamp = avg_changes_per_timestamp[avg_changes_per_timestamp.changes_per_timestamp > 1.]

num = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].shape[0]
print(f'There are {num} bots')

bot_sample_df = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].sample(num)
not_bot_sample_df = avg_changes_per_timestamp[~avg_changes_per_timestamp.bot].sample(num)

sample_df = pd.concat([bot_sample_df, not_bot_sample_df])

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes_per_timestamp:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user'), alt.Tooltip('changes_per_timestamp:Q')]
).properties(
    width = 600,
    height = 400,
    title = 'Number of changes by user per timestamp with more than 1 change'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [
        alt.Tooltip('count()', title='No of users'), 
        alt.Tooltip('bot')
    ]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart_counts | chart_bots
# Out:
# There are 36 bots
# alt.HConcatChart(...)

# %%
sample_df[['changes_per_timestamp', 'bot']].groupby('bot').mean()
# Out:
#        changes_per_timestamp
# bot
# False               1.863656
# True                1.509182

# %%
temp = df_edits[['user', 'timestamp', 'bot']].value_counts().groupby('user').max().reset_index()
temp[temp.user == 'Raugeier']
# Out:
#           user   0
# 4903  Raugeier  22

# %%
df_edits[(df_edits.user == 'Raugeier')&(df_edits.timestamp == 1633642165)]
# Out:
#       Unnamed: 0                        $schema  \
# 4005        4005  /mediawiki/recentchange/1.0.0
# 4006        4006  /mediawiki/recentchange/1.0.0
# 4007        4007  /mediawiki/recentchange/1.0.0
# 4008        4008  /mediawiki/recentchange/1.0.0
# 4009        4009  /mediawiki/recentchange/1.0.0
# 4010        4010  /mediawiki/recentchange/1.0.0
# 4011        4011  /mediawiki/recentchange/1.0.0
# 4012        4012  /mediawiki/recentchange/1.0.0
# 4013        4013  /mediawiki/recentchange/1.0.0
# 4015        4015  /mediawiki/recentchange/1.0.0
# 4018        4018  /mediawiki/recentchange/1.0.0
# 4019        4019  /mediawiki/recentchange/1.0.0
# 4021        4021  /mediawiki/recentchange/1.0.0
# 4022        4022  /mediawiki/recentchange/1.0.0
# 4023        4023  /mediawiki/recentchange/1.0.0
# 4025        4025  /mediawiki/recentchange/1.0.0
# 4029        4029  /mediawiki/recentchange/1.0.0
# 4030        4030  /mediawiki/recentchange/1.0.0
# 4032        4032  /mediawiki/recentchange/1.0.0
# 4039        4039  /mediawiki/recentchange/1.0.0
# 4045        4045  /mediawiki/recentchange/1.0.0
# 4047        4047  /mediawiki/recentchange/1.0.0
#
#                                                    meta            id  type  \
# 4005  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4006  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4007  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4008  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4009  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4010  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4011  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4012  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4013  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4015  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4018  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4019  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4021  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4022  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4023  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4025  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4029  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4030  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4032  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4039  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4045  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
# 4047  {'uri': 'https://commons.wikimedia.org/wiki/Fi...  1.784986e+09  edit
#
#       namespace                                           title  \
# 4005          6    File:St. Nicolai in Gödringen -3351-Pano.jpg
# 4006          6     File:St. Nicolai in Gödringen-4624-Pano.jpg
# 4007          6          File:St. Nicolai in Gödringen-3384.jpg
# 4008          6          File:St. Nicolai in Gödringen-3404.jpg
# 4009          6          File:St. Nicolai in Gödringen-4620.jpg
# 4010          6          File:St. Nicolai in Gödringen-3362.jpg
# 4011          6          File:St. Nicolai in Gödringen-3259.jpg
# 4012          6          File:St. Nicolai in Gödringen-3300.jpg
# 4013          6          File:St. Nicolai in Gödringen-3327.jpg
# 4015          6  File:Ehemaliges Parrhaus (Gödringen) -3409.jpg
# 4018          6          File:St. Nicolai in Gödringen-3315.jpg
# 4019          6          File:St. Nicolai in Gödringen-3312.jpg
# 4021          6     File:St. Nicolai in Gödringen-4612 Pano.jpg
# 4022          6          File:St. Nicolai in Gödringen-3333.jpg
# 4023          6          File:St. Nicolai in Gödringen-3321.jpg
# 4025          6          File:St. Nicolai in Gödringen-3263.jpg
# 4029          6          File:St. Nicolai in Gödringen-3282.jpg
# 4030          6          File:St. Nicolai in Gödringen-3291.jpg
# 4032          6          File:St. Nicolai in Gödringen-3369.jpg
# 4039          6          File:St. Nicolai in Gödringen-4611.jpg
# 4045          6          File:St. Nicolai in Gödringen-3255.jpg
# 4047          6          File:St. Nicolai in Gödringen-4608.jpg
#
#                                                 comment   timestamp      user  \
# 4005  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4006  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4007  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4008  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4009  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4010  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4011  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4012  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4013  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4015  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4018  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4019  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4021  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4022  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4023  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4025  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4029  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4030  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4032  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4039  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4045  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
# 4047  Removing from [[Category:Images from Lower Sax...  1633642165  Raugeier
#
#         bot minor patrolled                      length  \
# 4005  False  True      True  {'old': 4128, 'new': 4059}
# 4006  False  True      True  {'old': 2402, 'new': 2332}
# 4007  False  True      True  {'old': 2109, 'new': 2039}
# 4008  False  True      True  {'old': 2152, 'new': 2082}
# 4009  False  True      True  {'old': 2183, 'new': 2113}
# 4010  False  True      True  {'old': 2155, 'new': 2085}
# 4011  False  True      True  {'old': 2154, 'new': 2084}
# 4012  False  True      True  {'old': 2161, 'new': 2091}
# 4013  False  True      True  {'old': 2153, 'new': 2083}
# 4015  False  True      True  {'old': 3813, 'new': 3743}
# 4018  False  True      True  {'old': 3766, 'new': 3696}
# 4019  False  True      True  {'old': 2161, 'new': 2091}
# 4021  False  True      True  {'old': 2175, 'new': 2105}
# 4022  False  True      True  {'old': 2153, 'new': 2083}
# 4023  False  True      True  {'old': 2152, 'new': 2082}
# 4025  False  True      True  {'old': 2160, 'new': 2090}
# 4029  False  True      True  {'old': 2156, 'new': 2086}
# 4030  False  True      True  {'old': 2155, 'new': 2085}
# 4032  False  True      True  {'old': 2103, 'new': 2033}
# 4039  False  True      True  {'old': 3780, 'new': 3710}
# 4045  False  True      True  {'old': 2226, 'new': 2156}
# 4047  False  True      True  {'old': 2226, 'new': 2156}
#
#                                   revision                     server_url  \
# 4005  {'old': 593273218, 'new': 596627307}  https://commons.wikimedia.org
# 4006  {'old': 590529766, 'new': 596627314}  https://commons.wikimedia.org
# 4007  {'old': 593271182, 'new': 596627319}  https://commons.wikimedia.org
# 4008  {'old': 593271297, 'new': 596627308}  https://commons.wikimedia.org
# 4009  {'old': 591791253, 'new': 596627316}  https://commons.wikimedia.org
# 4010  {'old': 590529927, 'new': 596627317}  https://commons.wikimedia.org
# 4011  {'old': 593270776, 'new': 596627310}  https://commons.wikimedia.org
# 4012  {'old': 590530180, 'new': 596627312}  https://commons.wikimedia.org
# 4013  {'old': 590528880, 'new': 596627324}  https://commons.wikimedia.org
# 4015  {'old': 592631375, 'new': 596627325}  https://commons.wikimedia.org
# 4018  {'old': 592631986, 'new': 596627321}  https://commons.wikimedia.org
# 4019  {'old': 590530117, 'new': 596627327}  https://commons.wikimedia.org
# 4021  {'old': 590529722, 'new': 596627323}  https://commons.wikimedia.org
# 4022  {'old': 593271114, 'new': 596627326}  https://commons.wikimedia.org
# 4023  {'old': 593271041, 'new': 596627322}  https://commons.wikimedia.org
# 4025  {'old': 593270847, 'new': 596627306}  https://commons.wikimedia.org
# 4029  {'old': 593270917, 'new': 596627328}  https://commons.wikimedia.org
# 4030  {'old': 590529981, 'new': 596627311}  https://commons.wikimedia.org
# 4032  {'old': 590528598, 'new': 596627309}  https://commons.wikimedia.org
# 4039  {'old': 592631992, 'new': 596627320}  https://commons.wikimedia.org
# 4045  {'old': 593273138, 'new': 596627315}  https://commons.wikimedia.org
# 4047  {'old': 593271409, 'new': 596627318}  https://commons.wikimedia.org
#
#                 server_name server_script_path         wiki  \
# 4005  commons.wikimedia.org                 /w  commonswiki
# 4006  commons.wikimedia.org                 /w  commonswiki
# 4007  commons.wikimedia.org                 /w  commonswiki
# 4008  commons.wikimedia.org                 /w  commonswiki
# 4009  commons.wikimedia.org                 /w  commonswiki
# 4010  commons.wikimedia.org                 /w  commonswiki
# 4011  commons.wikimedia.org                 /w  commonswiki
# 4012  commons.wikimedia.org                 /w  commonswiki
# 4013  commons.wikimedia.org                 /w  commonswiki
# 4015  commons.wikimedia.org                 /w  commonswiki
# 4018  commons.wikimedia.org                 /w  commonswiki
# 4019  commons.wikimedia.org                 /w  commonswiki
# 4021  commons.wikimedia.org                 /w  commonswiki
# 4022  commons.wikimedia.org                 /w  commonswiki
# 4023  commons.wikimedia.org                 /w  commonswiki
# 4025  commons.wikimedia.org                 /w  commonswiki
# 4029  commons.wikimedia.org                 /w  commonswiki
# 4030  commons.wikimedia.org                 /w  commonswiki
# 4032  commons.wikimedia.org                 /w  commonswiki
# 4039  commons.wikimedia.org                 /w  commonswiki
# 4045  commons.wikimedia.org                 /w  commonswiki
# 4047  commons.wikimedia.org                 /w  commonswiki
#
#                                           parsedcomment  log_id log_type  \
# 4005  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4006  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4007  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4008  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4009  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4010  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4011  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4012  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4013  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4015  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4018  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4019  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4021  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4022  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4023  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4025  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4029  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4030  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4032  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4039  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4045  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
# 4047  Removing from <a href="/wiki/Category:Images_f...     NaN      NaN
#
#      log_action log_params log_action_comment    timestamp_parsed
# 4005        NaN        NaN                NaN 2021-10-08 00:29:25
# 4006        NaN        NaN                NaN 2021-10-08 00:29:25
# 4007        NaN        NaN                NaN 2021-10-08 00:29:25
# 4008        NaN        NaN                NaN 2021-10-08 00:29:25
# 4009        NaN        NaN                NaN 2021-10-08 00:29:25
# 4010        NaN        NaN                NaN 2021-10-08 00:29:25
# 4011        NaN        NaN                NaN 2021-10-08 00:29:25
# 4012        NaN        NaN                NaN 2021-10-08 00:29:25
# 4013        NaN        NaN                NaN 2021-10-08 00:29:25
# 4015        NaN        NaN                NaN 2021-10-08 00:29:25
# 4018        NaN        NaN                NaN 2021-10-08 00:29:25
# 4019        NaN        NaN                NaN 2021-10-08 00:29:25
# 4021        NaN        NaN                NaN 2021-10-08 00:29:25
# 4022        NaN        NaN                NaN 2021-10-08 00:29:25
# 4023        NaN        NaN                NaN 2021-10-08 00:29:25
# 4025        NaN        NaN                NaN 2021-10-08 00:29:25
# 4029        NaN        NaN                NaN 2021-10-08 00:29:25
# 4030        NaN        NaN                NaN 2021-10-08 00:29:25
# 4032        NaN        NaN                NaN 2021-10-08 00:29:25
# 4039        NaN        NaN                NaN 2021-10-08 00:29:25
# 4045        NaN        NaN                NaN 2021-10-08 00:29:25
# 4047        NaN        NaN                NaN 2021-10-08 00:29:25

# %%
from datetime import datetime

df_edits['timestamp_parsed'] = df_edits.timestamp.map(lambda x: datetime.fromtimestamp(x))

avg_changes_per_timestamp = df_edits[['user', 'timestamp']].value_counts().groupby('user').mean().reset_index()
avg_changes_per_timestamp.columns = ['user', 'changes_per_timestamp']
avg_changes_per_timestamp['bot'] = avg_changes_per_timestamp.user.map(lambda x: gd_dict[x])

np.random.seed(42)

avg_changes_per_timestamp = avg_changes_per_timestamp[avg_changes_per_timestamp.changes_per_timestamp > 1.]

num = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].shape[0]
print(f'There are {num} bots')

bot_sample_df = avg_changes_per_timestamp[avg_changes_per_timestamp.bot].sample(num)
not_bot_sample_df = avg_changes_per_timestamp[~avg_changes_per_timestamp.bot].sample(num)

sample_df = pd.concat([bot_sample_df, not_bot_sample_df])
sample_df = sample_df[sample_df.changes_per_timestamp < 4]

chart_counts = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('user', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('changes_per_timestamp:Q'),
    color = alt.Color('bot:N'),
    tooltip = [alt.Tooltip('user'), alt.Tooltip('changes_per_timestamp:Q')]
).properties(
    width = 600,
    height = 400,
    title = 'Max of changes by user per timestamp with more than 1 change'
)

chart_bots = alt.Chart(sample_df).mark_area(
    interpolate='step'
).encode(
    x = alt.X('bot:N', axis=alt.Axis(labels=False, ticks=False)),
    y = alt.Y('count()', title='count'),
    tooltip = [
        alt.Tooltip('count()', title='No of users'), 
        alt.Tooltip('bot')
    ]
).properties(
    width = 200,
    height = 400,
    title = 'Number of bots'
)

chart_counts | chart_bots
# Out:
# /tmp/ipykernel_14190/3374665770.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_edits['timestamp_parsed'] = df_edits.timestamp.map(lambda x: datetime.fromtimestamp(x))
# There are 36 bots
# alt.HConcatChart(...)

# %%
avg_changes_per_timestamp[avg_changes_per_timestamp.user == 'Raugeier']
# Out:
#           user  changes_per_timestamp    bot
# 4903  Raugeier                     22  False
